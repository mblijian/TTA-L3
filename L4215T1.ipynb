# %%
from ugot import ugot
got = ugot.UGOT()
# initialize
got.initialize('192.168.1.188')
print("UGOT is ready.")
# Out:
# 192.168.1.188:50051
# UGOT is ready.

# %% [markdown]
# # Level 4 Term 1

# %% [markdown]
# ## Session 1

# %% [markdown]
# 1. Syntax

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Hello my name is Mr.Li, I am a teacher.")
# Out:
# Hello my name is Mr.Li, I am a teacher.

# %% [markdown]
# 2. Indentation

# %%
print("Hello World!")
print("Hello my name is Mr.Li, I am a teacher.")
# Out:
# Hello World!
# Hello my name is Mr.Li, I am a teacher.

# %%
print("Hello World!")
    print("Hello my name is Mr.Li, I am a teacher.")
# Out:
#   Cell In[11], line 2
#     print("Hello my name is Mr.Li, I am a teacher.")
#     ^
# IndentationError: unexpected indent

# %%
if 7>5:
print("7 is greater than 5.")
# Out:
#   Cell In[13], line 2
#     print("7 is greater than 5.")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
if 7>5:
    print("7 is greater than 5.")
# Out:
# 7 is greater than 5.

# %% [markdown]
# 3. UGOT control

# %%
got.mecanum_move_speed_times(0,30,50,1)
got.mecanum_move_speed_times(1,30,50,1)

# %%
got.mecanum_turn_speed_times(2,30,90,2)

# %%
got.mecanum_move_speed_times(0,30,50,1)
got.mecanum_turn_speed_times(2,30,90,2)
got.mecanum_move_speed_times(0,30,50,1)
got.mecanum_turn_speed_times(2,30,90,2)
got.mecanum_move_speed_times(0,30,50,1)
got.mecanum_turn_speed_times(2,30,90,2)
got.mecanum_move_speed_times(0,30,50,1)
got.mecanum_turn_speed_times(2,30,90,2)

# %% [markdown]
# ## Session 2

# %% [markdown]
# 1. string, integer and float

# %%
# string: text
print("My name is Mr.Li")

# integer: whole number
print("7+8")
print(7+8)

# float
print("7.0+8.0")
print(7.0+8.0)
# Out:
# My name is Mr.Li
# 7+8
# 15
# 7.0+8.0
# 15.0

# %%
got.mecanum_move_speed_times(0,30,50,1)

# %% [markdown]
# 2. variable

# %%
name = "John"
age = 12
country = "Singapore"
print("Hello,my name is",name,"I am",age,"years old now.I was born in",country,"and it is a beautiful country.")
# Out:
# Hello,my name is John I am 12 years old now.I was born in Singapore and it is a beautiful country.

# %% [markdown]
# 3. f-string

# %%
name = "John"
age = 12
country = "Singapore"
print(f"Hello,my name is {name} I am {age} years old now.I was born in {country} and it is a beautiful country.")
# Out:
# Hello,my name is John I am 12 years old now.I was born in Singapore and it is a beautiful country.

# %%
name ="John"
age = 1000
food = "shark"
color ="blue"
sports ="swimming in the sun"
print(f"Hello, my name is {name}, I am {age} years old and I like {food},{color} and {sports}")
# Out:
# Hello, my name is John, I am 1000 years old and I like shark,blue and swimming in the sun
